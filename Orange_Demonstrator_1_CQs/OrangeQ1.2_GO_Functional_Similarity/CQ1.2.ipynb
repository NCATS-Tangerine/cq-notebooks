# %%
import pandas as pd
import requests
from pprint import pprint
import ontobio

# %%
# get gene sets from github
base_url = "https://raw.githubusercontent.com/NCATS-Tangerine/cq-notebooks/master/FA_gene_sets/"
FA_1_core_complex = "FA_1_core_complex.txt"
columns = ['gene_curie', 'gene_symbol']
fa_genes = pd.read_csv(base_url + FA_1_core_complex, sep='\t', names=columns)

# %%
fa_genes
# Out:
#         gene_curie gene_symbol
# 0    NCBIGene:2175       FANCA
# 1    NCBIGene:2187       FANCB
# 2    NCBIGene:2176       FANCC
# 3    NCBIGene:2178       FANCE
# 4    NCBIGene:2188       FANCF
# 5    NCBIGene:2189       FANCG
# 6   NCBIGene:55120       FANCL
# 7   NCBIGene:57697       FANCM
# 8    NCBIGene:2177      FANCD2
# 9   NCBIGene:55215       FANCI
# 10  NCBIGene:29089       UBE2T

# %%
class BioLinkWrapper(object):
    def __init__(self):
        self.endpoint = 'https://api.monarchinitiative.org/api/'
        
    def get_gene(self, gene_curie):
        url = '{}bioentity/gene/{}'.format(self.endpoint, gene_curie)
        response = requests.get(url)
        return response.json()

    def get_orthologs(self, gene_curie):
        url = '{}bioentity/gene/{}/homologs/'.format(self.endpoint, gene_curie)
        response = requests.get(url)
        return response.json()

    def get_phenotypes(self,gene_curie):
        url = '{}bioentity/gene/{}/phenotypes/'.format(self.endpoint, gene_curie)
        response = requests.get(url)
        return response.json()
    
    def get_diseases(self, gene_curie):
        url = '{}bioentity/gene/{}/diseases/'.format(self.endpoint, gene_curie)
        response = requests.get(url)
        return response.json()
    
    def get_interactions(self, gene_curie):
        url = '{}bioentity/gene/{}/interactions/'.format(self.endpoint, gene_curie)
        response = requests.get(url)
        return response.json()
    
    def get_functions(self, gene_curie):
        url = '{}bioentity/gene/{}/functions/'.format(self.endpoint, gene_curie)
        response = requests.get(url)
        return response.json()
    
    def get_disease_models(self, disease_curie):
        url = '{}/bioentity/disease/{}/models/'.format(self.endpoint, disease_curie)
        response = requests.get(url)
        return response.json()
    
    def get_all_phenotypes_for_taxon(self, taxon_curie):
        # get phenotypes associated with taxid
        url = "mart/gene/phenotype/{}".format(self.endpoint, taxon_curie)
        response = requests.get(url)
        return response.json()
    
    def get_gene_function(self, gene_curie):
        # get function associated with gene
        url = "{}bioentity/gene/{}/function/".format(self.endpoint, gene_curie)
        response = requests.get(url)
        return response.json()

# %% [markdown]
# # Get orthologs

# %%
fa_genes_orthologs = list()
BLW = BioLinkWrapper()
for index, gene in fa_genes.iterrows():
    orthologs = BLW.get_orthologs(gene[0])
    for orth in orthologs['associations']:
        orth_dict = {
            'gene_name': gene[1],
            'gene_curie': gene[0],
            'ortholog_name': orth['object']['label'],
            'ortholog_curie': orth['object']['id'],
            'orth_tax_label': orth['object']['taxon']['label'],
            'orth_tax_id': orth['object']['taxon']['id']
        }
        fa_genes_orthologs.append(orth_dict)

# %%
orth_columns  = [ 'gene_name', 'gene_curie', 'ortholog_name', 'ortholog_curie', 'orth_tax_label', 'orth_tax_id']
orth_df = pd.DataFrame(data=fa_genes_orthologs, columns=orth_columns)
orth_df
# Out:
#     gene_name      gene_curie ortholog_name             ortholog_curie  \
# 0       FANCA   NCBIGene:2175         Fanca                RGD:1311380
# 1       FANCA   NCBIGene:2175         FANCA         NCBIGene:100621453
# 2       FANCA   NCBIGene:2175         FANCA         NCBIGene:100052495
# 3       FANCA   NCBIGene:2175         Fanca                MGI:1341823
# 4       FANCA   NCBIGene:2175         FANCA         NCBIGene:100080126
# 5       FANCA   NCBIGene:2175         FANCA            NCBIGene:415854
# 6       FANCA   NCBIGene:2175         FANCA            NCBIGene:454393
# 7       FANCA   NCBIGene:2175         FANCA            NCBIGene:618375
# 8       FANCA   NCBIGene:2175         FANCA         NCBIGene:100027499
# 9       FANCB   NCBIGene:2187         FANCB            NCBIGene:616549
# 10      FANCB   NCBIGene:2187         Fancb                RGD:1561555
# 11      FANCB   NCBIGene:2187         fancb         NCBIGene:100564315
# 12      FANCB   NCBIGene:2187         FANCB            NCBIGene:418628
# 13      FANCB   NCBIGene:2187         Fancb                MGI:2448558
# 14      FANCB   NCBIGene:2187         fancb     ZFIN:ZDB-GENE-060510-1
# 15      FANCB   NCBIGene:2187         FANCB         NCBIGene:100156438
# 16      FANCB   NCBIGene:2187         FANCB         NCBIGene:100055607
# 17      FANCB   NCBIGene:2187         FANCB            NCBIGene:712083
# 18      FANCB   NCBIGene:2187         FANCB            NCBIGene:737001
# 19      FANCB   NCBIGene:2187         FANCB         NCBIGene:100031860
# 20      FANCC   NCBIGene:2176         FANCC         NCBIGene:100061359
# 21      FANCC   NCBIGene:2176         fancc         NCBIGene:100555906
# 22      FANCC   NCBIGene:2176         Fancc                   RGD:2593
# 23      FANCC   NCBIGene:2176         FANCC            NCBIGene:427468
# 24      FANCC   NCBIGene:2176         Fancc                  MGI:95480
# 25      FANCC   NCBIGene:2176         fancc     Xenbase:XB-GENE-986037
# 26      FANCC   NCBIGene:2176         FANCC         NCBIGene:100013900
# 27      FANCC   NCBIGene:2176         fancc     ZFIN:ZDB-GENE-060510-2
# 28      FANCC   NCBIGene:2176         FANCC            NCBIGene:465257
# 29      FANCC   NCBIGene:2176         FANCC            NCBIGene:709398
# ..        ...             ...           ...                        ...
# 89     FANCD2   NCBIGene:2177        FANCD2            NCBIGene:460163
# 90     FANCD2   NCBIGene:2177        FANCD2         NCBIGene:100051871
# 91     FANCD2   NCBIGene:2177        fancd2     Xenbase:XB-GENE-984801
# 92     FANCD2   NCBIGene:2177         fcd-2    WormBase:WBGene00012767
# 93     FANCD2   NCBIGene:2177        fancd2     ZFIN:ZDB-GENE-040116-5
# 94     FANCD2   NCBIGene:2177        Fancd2                MGI:2448480
# 95     FANCD2   NCBIGene:2177        Fancd2        FlyBase:FBgn0038827
# 96     FANCD2   NCBIGene:2177        Fancd2                RGD:1303172
# 97      FANCI  NCBIGene:55215         FANCI            NCBIGene:415491
# 98      FANCI  NCBIGene:55215         fanci  ZFIN:ZDB-GENE-030131-2905
# 99      FANCI  NCBIGene:55215         FANCI         NCBIGene:100156260
# 100     FANCI  NCBIGene:55215         FANCI         NCBIGene:100016421
# 101     FANCI  NCBIGene:55215         FANCI        FlyBase:FBgn0033354
# 102     FANCI  NCBIGene:55215         FANCI         NCBIGene:100069712
# 103     FANCI  NCBIGene:55215     AT5G49110            NCBIGene:834970
# 104     FANCI  NCBIGene:55215         fanci         NCBIGene:100552745
# 105     FANCI  NCBIGene:55215         FANCI            NCBIGene:699878
# 106     FANCI  NCBIGene:55215        fnci-1    WormBase:WBGene00020935
# 107     FANCI  NCBIGene:55215         Fanci                MGI:2384790
# 108     FANCI  NCBIGene:55215         Fanci                RGD:2321863
# 109     FANCI  NCBIGene:55215         FANCI            NCBIGene:453636
# 110     FANCI  NCBIGene:55215         FANCI            NCBIGene:522442
# 111     UBE2T  NCBIGene:29089         UBE2T            NCBIGene:505314
# 112     UBE2T  NCBIGene:29089         ube2t         NCBIGene:100567260
# 113     UBE2T  NCBIGene:29089         Ube2t                RGD:1310816
# 114     UBE2T  NCBIGene:29089         Ube2t                MGI:1914446
# 115     UBE2T  NCBIGene:29089         UBE2T            NCBIGene:421149
# 116     UBE2T  NCBIGene:29089         UBE2T            NCBIGene:705911
# 117     UBE2T  NCBIGene:29089         ube2t   ZFIN:ZDB-GENE-061013-547
# 118     UBE2T  NCBIGene:29089         UBE2T            NCBIGene:457628
#
#                     orth_tax_label      orth_tax_id
# 0                Rattus norvegicus  NCBITaxon:10116
# 1                       Sus scrofa   NCBITaxon:9823
# 2                   Equus caballus   NCBITaxon:9796
# 3                     Mus musculus  NCBITaxon:10090
# 4         Ornithorhynchus anatinus   NCBITaxon:9258
# 5                    Gallus gallus   NCBITaxon:9031
# 6                  Pan troglodytes   NCBITaxon:9598
# 7                       Bos taurus   NCBITaxon:9913
# 8            Monodelphis domestica  NCBITaxon:13616
# 9                       Bos taurus   NCBITaxon:9913
# 10               Rattus norvegicus  NCBITaxon:10116
# 11             Anolis carolinensis  NCBITaxon:28377
# 12                   Gallus gallus   NCBITaxon:9031
# 13                    Mus musculus  NCBITaxon:10090
# 14                     Danio rerio   NCBITaxon:7955
# 15                      Sus scrofa   NCBITaxon:9823
# 16                  Equus caballus   NCBITaxon:9796
# 17                  Macaca mulatta   NCBITaxon:9544
# 18                 Pan troglodytes   NCBITaxon:9598
# 19           Monodelphis domestica  NCBITaxon:13616
# 20                  Equus caballus   NCBITaxon:9796
# 21             Anolis carolinensis  NCBITaxon:28377
# 22               Rattus norvegicus  NCBITaxon:10116
# 23                   Gallus gallus   NCBITaxon:9031
# 24                    Mus musculus  NCBITaxon:10090
# 25   Xenopus (Silurana) tropicalis   NCBITaxon:8364
# 26           Monodelphis domestica  NCBITaxon:13616
# 27                     Danio rerio   NCBITaxon:7955
# 28                 Pan troglodytes   NCBITaxon:9598
# 29                  Macaca mulatta   NCBITaxon:9544
# ..                             ...              ...
# 89                 Pan troglodytes   NCBITaxon:9598
# 90                  Equus caballus   NCBITaxon:9796
# 91   Xenopus (Silurana) tropicalis   NCBITaxon:8364
# 92          Caenorhabditis elegans   NCBITaxon:6239
# 93                     Danio rerio   NCBITaxon:7955
# 94                    Mus musculus  NCBITaxon:10090
# 95         Drosophila melanogaster   NCBITaxon:7227
# 96               Rattus norvegicus  NCBITaxon:10116
# 97                   Gallus gallus   NCBITaxon:9031
# 98                     Danio rerio   NCBITaxon:7955
# 99                      Sus scrofa   NCBITaxon:9823
# 100          Monodelphis domestica  NCBITaxon:13616
# 101        Drosophila melanogaster   NCBITaxon:7227
# 102                 Equus caballus   NCBITaxon:9796
# 103           Arabidopsis thaliana   NCBITaxon:3702
# 104            Anolis carolinensis  NCBITaxon:28377
# 105                 Macaca mulatta   NCBITaxon:9544
# 106         Caenorhabditis elegans   NCBITaxon:6239
# 107                   Mus musculus  NCBITaxon:10090
# 108              Rattus norvegicus  NCBITaxon:10116
# 109                Pan troglodytes   NCBITaxon:9598
# 110                     Bos taurus   NCBITaxon:9913
# 111                     Bos taurus   NCBITaxon:9913
# 112            Anolis carolinensis  NCBITaxon:28377
# 113              Rattus norvegicus  NCBITaxon:10116
# 114                   Mus musculus  NCBITaxon:10090
# 115                  Gallus gallus   NCBITaxon:9031
# 116                 Macaca mulatta   NCBITaxon:9544
# 117                    Danio rerio   NCBITaxon:7955
# 118                Pan troglodytes   NCBITaxon:9598
#
# [119 rows x 6 columns]

# %%
def query_mygene(gene_curie):
    gene_curie = gene_curie.replace('NCBIGene:', '')
    url = 'https://mygene.info/v3/query?q={}&fields=all'.format(gene_curie)
    hit = requests.get(url)
    hit = hit.json()
    ukb = 'UniProtKB:{}'.format(hit['hits'][0]['uniprot']['Swiss-Prot'])
    return ukb

# %%
orth_df.head()

# %%
from ontobio.ontol_factory import OntologyFactory

# Create ontology object, for GO
# Transparently uses remote SPARQL service.
# (May take a few seconds to run first time, Jupyter will show '*'. BE PATIENT, do
# not re-execute cell)
ofactory = OntologyFactory()
ont = ofactory.create('go')

# %%
from ontobio.io.gafparser import GafParser
from ontobio.assoc_factory import AssociationSetFactory

p = GafParser()
afactory = AssociationSetFactory()

def make_assocs(group):
    url = "http://geneontology.org/gene-associations/gene_association.{}.gz".format(group)
    if group == 'human':
        url = "http://geneontology.org/gene-associations/goa_human.gaf.gz"
    assocs = p.parse(url)
    return afactory.create_from_assocs(assocs, ontology=ont)

# %%
asoc_mouse = make_assocs('mgi')

# %%
mouse_orthologs = orth_df.loc[orth_df['orth_tax_id'] == 'NCBITaxon:10090']
mouse_ortho_sims = list()
for index, row in mouse_orthologs.iterrows():
    gene_name = row[0]
    gene_curie = row[1]
    ortholog_name = row[2]
    ortholog_curie = row[3]
    ortholog_taxon_curie = row[4]
    ortholog_taxon_name = row[5]
    mo = 'MGI:{}'.format(ortholog_curie)
    for mgene in list(asoc_mouse.subject_label_map.keys()):
        amScore = asoc_mouse.jaccard_similarity(mo, mgene)     
        if amScore > .7 and amScore < 1:
            mouse_ortho_sims.append({
                    'gene_name': gene_name,
                    'gene_curie': gene_curie,
                    'ortholog_name': ortholog_name,
                    'ortholog_curie': row[3],
                    'ortholog_taxon_curie': row[4],
                    'ortholog_taxon_name': row[5],
                    'non_fa_hit_name': asoc_mouse.label(mgene),
                    'non_fa_hit_curie': mgene.replace('MGI:MGI:', 'MGI:'),
                    'sim_score' : amScore
                })

# %%
mouse_sims_columns = [ 'gene_name','gene_curie', 'ortholog_name', 
                      'ortholog_curie', 'ortholog_taxon_curie', 
                      'ortholog_taxon_name', 'non_fa_hit_name', 'non_fa_hit_curie', 'sim_score' ]
mouse_sims_df = pd.DataFrame(data=mouse_ortho_sims, columns=mouse_sims_columns )

# %%
mouse_sims_df
# Out:
#    gene_name      gene_curie ortholog_name ortholog_curie  \
# 0      FANCA   NCBIGene:2175         Fanca    MGI:1341823
# 1      FANCE   NCBIGene:2178         Fance    MGI:1920025
# 2      FANCE   NCBIGene:2178         Fance    MGI:1920025
# 3      FANCE   NCBIGene:2178         Fance    MGI:1920025
# 4      FANCE   NCBIGene:2178         Fance    MGI:1920025
# 5      FANCE   NCBIGene:2178         Fance    MGI:1920025
# 6      FANCE   NCBIGene:2178         Fance    MGI:1920025
# 7      FANCE   NCBIGene:2178         Fance    MGI:1920025
# 8      FANCE   NCBIGene:2178         Fance    MGI:1920025
# 9      FANCE   NCBIGene:2178         Fance    MGI:1920025
# 10     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 11     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 12     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 13     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 14     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 15     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 16     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 17     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 18     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 19     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 20     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 21     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 22     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 23     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 24     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 25     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 26     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 27     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 28     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 29     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 30     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 31     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 32     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 33     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 34     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 35     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 36     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 37     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 38     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 39     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 40     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 41     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 42     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 43     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 44     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 45     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 46     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 47     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 48     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 49     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 50     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 51     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 52     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 53     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 54     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 55     FANCE   NCBIGene:2178         Fance    MGI:1920025
# 56    FANCD2   NCBIGene:2177        Fancd2    MGI:2448480
# 57     UBE2T  NCBIGene:29089         Ube2t    MGI:1914446
#
#    ortholog_taxon_curie ortholog_taxon_name non_fa_hit_name non_fa_hit_curie  \
# 0          Mus musculus     NCBITaxon:10090          Fancd2      MGI:2448480
# 1          Mus musculus     NCBITaxon:10090          Cfap45      MGI:1919120
# 2          Mus musculus     NCBITaxon:10090           Fnbp4      MGI:1860513
# 3          Mus musculus     NCBITaxon:10090            Rnu6        MGI:97989
# 4          Mus musculus     NCBITaxon:10090           Rprd2      MGI:1922387
# 5          Mus musculus     NCBITaxon:10090         Caskin2      MGI:2157062
# 6          Mus musculus     NCBITaxon:10090          Zbtb34      MGI:2685195
# 7          Mus musculus     NCBITaxon:10090          Pwwp2b      MGI:2142008
# 8          Mus musculus     NCBITaxon:10090          Evx1os      MGI:1917843
# 9          Mus musculus     NCBITaxon:10090           Lyrm1      MGI:1921169
# 10         Mus musculus     NCBITaxon:10090           Hspb3      MGI:1928479
# 11         Mus musculus     NCBITaxon:10090         Fam124b      MGI:3026880
# 12         Mus musculus     NCBITaxon:10090         Snord21       MGI:102855
# 13         Mus musculus     NCBITaxon:10090           Cwc25      MGI:1914730
# 14         Mus musculus     NCBITaxon:10090            Cmip      MGI:1921690
# 15         Mus musculus     NCBITaxon:10090        AW549877      MGI:2146232
# 16         Mus musculus     NCBITaxon:10090   0610040J01Rik      MGI:1923511
# 17         Mus musculus     NCBITaxon:10090        BC005624      MGI:2385132
# 18         Mus musculus     NCBITaxon:10090         Hcfc1r1      MGI:2663619
# 19         Mus musculus     NCBITaxon:10090         Magea10      MGI:3588211
# 20         Mus musculus     NCBITaxon:10090   2200002D01Rik      MGI:1919525
# 21         Mus musculus     NCBITaxon:10090         Klhdc10      MGI:1924038
# 22         Mus musculus     NCBITaxon:10090   2310022A10Rik      MGI:1913617
# 23         Mus musculus     NCBITaxon:10090          Apold1      MGI:2685921
# 24         Mus musculus     NCBITaxon:10090          Prdm15      MGI:1930121
# 25         Mus musculus     NCBITaxon:10090           Wdr26      MGI:1923825
# 26         Mus musculus     NCBITaxon:10090          Zbtb11      MGI:2443876
# 27         Mus musculus     NCBITaxon:10090           Nol4l      MGI:1918765
# 28         Mus musculus     NCBITaxon:10090           Fem1c      MGI:2444737
# 29         Mus musculus     NCBITaxon:10090         Kansl1l      MGI:1915941
# 30         Mus musculus     NCBITaxon:10090      D8Ertd738e      MGI:1289231
# 31         Mus musculus     NCBITaxon:10090          Dcaf11        MGI:90168
# 32         Mus musculus     NCBITaxon:10090          Hirip3      MGI:2142364
# 33         Mus musculus     NCBITaxon:10090   1700030J22Rik      MGI:1916778
# 34         Mus musculus     NCBITaxon:10090           Wdr27      MGI:1918932
# 35         Mus musculus     NCBITaxon:10090          Zfp672      MGI:2442105
# 36         Mus musculus     NCBITaxon:10090          Fam76b      MGI:1920076
# 37         Mus musculus     NCBITaxon:10090          Nudt22      MGI:1915573
# 38         Mus musculus     NCBITaxon:10090   A230006K03Rik      MGI:3644205
# 39         Mus musculus     NCBITaxon:10090             Mro      MGI:2152817
# 40         Mus musculus     NCBITaxon:10090          Nudcd1      MGI:1914679
# 41         Mus musculus     NCBITaxon:10090         Fam217b      MGI:1918782
# 42         Mus musculus     NCBITaxon:10090           Gpkow      MGI:1859610
# 43         Mus musculus     NCBITaxon:10090         Fam222b      MGI:2384939
# 44         Mus musculus     NCBITaxon:10090         Fam131b      MGI:1923406
# 45         Mus musculus     NCBITaxon:10090          Spin2d      MGI:1922101
# 46         Mus musculus     NCBITaxon:10090           Lyrm4      MGI:2683538
# 47         Mus musculus     NCBITaxon:10090   1110032A03Rik      MGI:1915971
# 48         Mus musculus     NCBITaxon:10090           Myct1      MGI:1915882
# 49         Mus musculus     NCBITaxon:10090         Plekhg1      MGI:2676551
# 50         Mus musculus     NCBITaxon:10090          Fam76a      MGI:2385211
# 51         Mus musculus     NCBITaxon:10090         Ankrd12      MGI:1914357
# 52         Mus musculus     NCBITaxon:10090        Tmem179b      MGI:1914956
# 53         Mus musculus     NCBITaxon:10090            Gid8      MGI:1923675
# 54         Mus musculus     NCBITaxon:10090          Magea4      MGI:1333839
# 55         Mus musculus     NCBITaxon:10090         Ccdc174      MGI:2444652
# 56         Mus musculus     NCBITaxon:10090           Fanca      MGI:1341823
# 57         Mus musculus     NCBITaxon:10090           Ube2w      MGI:1914049
#
#     sim_score
# 0    0.705882
# 1    0.833333
# 2    0.750000
# 3    0.807692
# 4    0.709677
# 5    0.730769
# 6    0.833333
# 7    0.833333
# 8    0.709677
# 9    0.714286
# 10   0.703704
# 11   0.740741
# 12   0.703704
# 13   0.807692
# 14   0.740741
# 15   0.740741
# 16   0.800000
# 17   0.740741
# 18   0.800000
# 19   0.740741
# 20   0.703704
# 21   0.800000
# 22   0.833333
# 23   0.740741
# 24   0.760000
# 25   0.740741
# 26   0.833333
# 27   0.703704
# 28   0.740741
# 29   0.724138
# 30   0.703704
# 31   0.724138
# 32   0.703704
# 33   0.740741
# 34   0.833333
# 35   0.791667
# 36   0.730769
# 37   0.769231
# 38   0.750000
# 39   0.703704
# 40   0.740741
# 41   0.740741
# 42   0.714286
# 43   0.833333
# 44   0.703704
# 45   0.740741
# 46   0.750000
# 47   0.833333
# 48   0.714286
# 49   0.833333
# 50   0.750000
# 51   0.740741
# 52   0.724138
# 53   0.800000
# 54   0.750000
# 55   0.833333
# 56   0.705882
# 57   0.732759

# %%
asoc_hsap = make_assocs('human')

# %%
hsap_ortho_sims = list()
for index, row in fa_genes.iterrows():
    ukb = query_mygene(row[0])
    for hgene in list(asoc_hsap.subject_label_map.keys()):
        amScore = asoc_hsap.jaccard_similarity(ukb, hgene)
        if amScore > .7 and amScore < 1:
            hsap_ortho_sims.append({
                    'gene_name': row[0],
                    'gene_curie': row[1],
                    'non_fa_hit_name': asoc_hsap.label(hgene),
                    'non_fa_hit_curie': hgene,
                    'sim_score' : amScore
                })

# %%
hsap_ortho_sim_columns = [ 'gene_name','gene_curie', 'non_fa_hit_name', 'non_fa_hit_curie', 'sim_score' ]
hsap_ortho_sims_df = pd.DataFrame(data=hsap_ortho_sims, columns=hsap_ortho_sim_columns )

# %%
hsap_ortho_sims_df
# Out:
#        gene_name gene_curie non_fa_hit_name  non_fa_hit_curie  sim_score
# 0  NCBIGene:2187      FANCB          FAAP24  UniProtKB:Q9BTP7   0.905660
# 1  NCBIGene:2187      FANCB         FAAP100  UniProtKB:Q0VG06   0.813559
# 2  NCBIGene:2187      FANCB           FANCE  UniProtKB:Q9HB96   0.958333
# 3  NCBIGene:2187      FANCB            INIP  UniProtKB:Q9NRY2   0.865385
# 4  NCBIGene:2178      FANCE          FAAP24  UniProtKB:Q9BTP7   0.867925
# 5  NCBIGene:2178      FANCE           FANCB  UniProtKB:Q8NB91   0.958333
# 6  NCBIGene:2178      FANCE         FAAP100  UniProtKB:Q0VG06   0.779661
# 7  NCBIGene:2178      FANCE            INIP  UniProtKB:Q9NRY2   0.826923

# %%
pwd
# Out:
# '/Users/timputman/CODE/NCATS/cq_notebooks/cq-notebooks/Orange_Demonstrator_1_CQs/OrangeQ1.2_GO_Functional_Similarity'
