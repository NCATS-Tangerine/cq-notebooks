# %%
import requests
import json
from pprint import pprint
import pandas as pd

# %% [markdown]
# ### General Solr Query

# %%
def query_solr(category, curie):
    solr_url = 'https://solr.monarchinitiative.org/solr/golr/select/'
    params = {
        'qt': 'standard',
        'wt': 'json',
        'rows': '250',
        'start': '0',
        'fl': '*,score',
        'fq': ['subject_category:"{}"'.format(category),'object_closure:"{}"'.format(curie)],
        'q': '*:*'
    }
    r = requests.get(solr_url, params)
    return json.loads(r.text)['response']

# %% [markdown]
# ### Gene 2 Variants Solr Query

# %%
def solr_gene2variants(gene_curie):
    variants = []
    data = query_solr('variant', gene_curie)
    for doc in data['docs']:
        ev_graph = json.loads(doc['evidence_graph'])
        variants.append(ev_graph['edges'][0]['sub'])
    return variants

# %% [markdown]
# ### Variant 2 Disease Solr Query

# %%
def query_solr_var2dis(varID):
    solr_url = 'https://solr.monarchinitiative.org/solr/golr/select/'
    params = {
        'qt': 'standard',
        'wt': 'json',
        'rows': '250',
        'start': '0',
        'fl': '*,score',
        'fq': [
            'object_category:"disease"',
            'subject_category:"variant"', 
            'subject_closure:"{}"'.format(varID)],
        'q': '*:*'
    }
    r = requests.get(solr_url, params)
    return json.loads(r.text)['response']

# %% [markdown]
# ### Get all FA Associated Genes

# %%
# get gene sets from github
base_url = "https://raw.githubusercontent.com/NCATS-Tangerine/cq-notebooks/master/FA_gene_sets/"
FA_all_genes = "FA_4_all_genes.txt"
columns = ['gene_curie', 'gene_symbol']
fa_genes = pd.read_csv(base_url + FA_all_genes, sep='\t', names=columns)
fa_genes
# Out:
#          gene_curie gene_symbol
# 0     NCBIGene:2175       FANCA
# 1     NCBIGene:2187       FANCB
# 2     NCBIGene:2176       FANCC
# 3     NCBIGene:2178       FANCE
# 4     NCBIGene:2188       FANCF
# 5     NCBIGene:2189       FANCG
# 6    NCBIGene:55120       FANCL
# 7    NCBIGene:57697       FANCM
# 8     NCBIGene:2177      FANCD2
# 9    NCBIGene:55215       FANCI
# 10   NCBIGene:29089       UBE2T
# 11     NCBIGene:675       BRCA2
# 12   NCBIGene:83990       BRIP1
# 13   NCBIGene:79728       PALB2
# 14    NCBIGene:5889      RAD51C
# 15   NCBIGene:84464        SLX4
# 16    NCBIGene:2072       ERCC4
# 17    NCBIGene:5888       RAD51
# 18     NCBIGene:672       BRCA1
# 19   NCBIGene:10459      MAD2L2
# 20    NCBIGene:7516       XRCC2
# 21   NCBIGene:55159       RFWD3
# 22   NCBIGene:80233     FAAP100
# 23   NCBIGene:91442      FAAP24
# 24  NCBIGene:199990      FAAP20
# 25  NCBIGene:378708       CENPS
# 26  NCBIGene:201254       CENPX

# %% [markdown]
# ### Useful Functions

# %%
def variant_count(val, dataframe, field):
    hits = dataframe.loc[dataframe[field] == val]
    return hits['variant_curie'].tolist()

# %%
tv_data = []
g2v2d_data = []
for index, row in fa_genes.iterrows():
    variants = solr_gene2variants(row[0])
    tot_var_results = {
        'gene_name': row[1], 
        'gene_curie': row[0], 
        '#variants': len(variants)
    }
    dis_count = 0
    unique_diseases = list()
    for var in variants:
        var2dis = query_solr_var2dis(varID=var)
        if var2dis['numFound'] != 0:
            if var2dis['docs'][0]['relation'] == 'GENO:0000841' or var2dis['docs'][0]['relation'] == 'GENO:0000840':
                dis_count += 1
                association = {
                    'gene_name': row[1],
                    'gene_curie': row[0],
                    'variant_name': var2dis['docs'][0]['subject_label'],
                    'variant_curie': var2dis['docs'][0]['subject'],
                    'relation_name': var2dis['docs'][0]['relation_label'],
                    'relation_curie': var2dis['docs'][0]['relation'],
                    'disease_curie': var2dis['docs'][0]['object'], 
                    'disease_name': var2dis['docs'][0]['object_label']
                }
                unique_diseases.append(var2dis['docs'][0]['object_label'])
                g2v2d_data.append(association)
    tot_var_results['#disease_variants'] = dis_count
    tot_var_results['#unique_diseases'] = len(set(unique_diseases))
    tv_data.append(tot_var_results)
tv_columns = ['gene_name', 'gene_curie', '#variants', '#disease_variants', '#unique_diseases']
total_variants = pd.DataFrame(data=tv_data, columns=tv_columns)
g2v2d_columns = ['gene_name', 'gene_curie', 'variant_name', 'variant_curie', 
                'relation_name', 'relation_curie', 'disease_name', 'disease_curie']
gene2variant2disease_table = pd.DataFrame(data=g2v2d_data, columns=g2v2d_columns)
gene2variant2disease_table.to_csv('FA_Pathogenic_variants_Solr.csv', sep=',')

# %%
total_variants
# Out:
#    gene_name       gene_curie  #variants  #disease_variants  #unique_diseases
# 0      FANCA    NCBIGene:2175        193                 32                 1
# 1      FANCB    NCBIGene:2187         45                  7                 1
# 2      FANCC    NCBIGene:2176        219                 41                 2
# 3      FANCE    NCBIGene:2178         34                  4                 2
# 4      FANCF    NCBIGene:2188         34                  6                 1
# 5      FANCG    NCBIGene:2189         37                  9                 1
# 6      FANCL   NCBIGene:55120         36                  7                 1
# 7      FANCM   NCBIGene:57697         44                  0                 0
# 8     FANCD2    NCBIGene:2177         74                  6                 1
# 9      FANCI   NCBIGene:55215         67                  7                 1
# 10     UBE2T   NCBIGene:29089          4                  2                 1
# 11     BRCA2     NCBIGene:675        250                129                 5
# 12     BRIP1   NCBIGene:83990        250                 30                 5
# 13     PALB2   NCBIGene:79728        250                 61                 3
# 14    RAD51C    NCBIGene:5889        197                 44                 2
# 15      SLX4   NCBIGene:84464        125                  6                 1
# 16     ERCC4    NCBIGene:2072         74                  8                 3
# 17     RAD51    NCBIGene:5888         10                  4                 3
# 18     BRCA1     NCBIGene:672        250                145                 3
# 19    MAD2L2   NCBIGene:10459          3                  1                 1
# 20     XRCC2    NCBIGene:7516         53                  0                 0
# 21     RFWD3   NCBIGene:55159          2                  0                 0
# 22   FAAP100   NCBIGene:80233          0                  0                 0
# 23    FAAP24   NCBIGene:91442          0                  0                 0
# 24    FAAP20  NCBIGene:199990          0                  0                 0
# 25     CENPS  NCBIGene:378708          0                  0                 0
# 26     CENPX  NCBIGene:201254          0                  0                 0

# %%
gene2variant2disease_table
# Out:
#     gene_name      gene_curie  \
# 0       FANCA   NCBIGene:2175
# 1       FANCA   NCBIGene:2175
# 2       FANCA   NCBIGene:2175
# 3       FANCA   NCBIGene:2175
# 4       FANCA   NCBIGene:2175
# 5       FANCA   NCBIGene:2175
# 6       FANCA   NCBIGene:2175
# 7       FANCA   NCBIGene:2175
# 8       FANCA   NCBIGene:2175
# 9       FANCA   NCBIGene:2175
# 10      FANCA   NCBIGene:2175
# 11      FANCA   NCBIGene:2175
# 12      FANCA   NCBIGene:2175
# 13      FANCA   NCBIGene:2175
# 14      FANCA   NCBIGene:2175
# 15      FANCA   NCBIGene:2175
# 16      FANCA   NCBIGene:2175
# 17      FANCA   NCBIGene:2175
# 18      FANCA   NCBIGene:2175
# 19      FANCA   NCBIGene:2175
# 20      FANCA   NCBIGene:2175
# 21      FANCA   NCBIGene:2175
# 22      FANCA   NCBIGene:2175
# 23      FANCA   NCBIGene:2175
# 24      FANCA   NCBIGene:2175
# 25      FANCA   NCBIGene:2175
# 26      FANCA   NCBIGene:2175
# 27      FANCA   NCBIGene:2175
# 28      FANCA   NCBIGene:2175
# 29      FANCA   NCBIGene:2175
# ..        ...             ...
# 519     BRCA1    NCBIGene:672
# 520     BRCA1    NCBIGene:672
# 521     BRCA1    NCBIGene:672
# 522     BRCA1    NCBIGene:672
# 523     BRCA1    NCBIGene:672
# 524     BRCA1    NCBIGene:672
# 525     BRCA1    NCBIGene:672
# 526     BRCA1    NCBIGene:672
# 527     BRCA1    NCBIGene:672
# 528     BRCA1    NCBIGene:672
# 529     BRCA1    NCBIGene:672
# 530     BRCA1    NCBIGene:672
# 531     BRCA1    NCBIGene:672
# 532     BRCA1    NCBIGene:672
# 533     BRCA1    NCBIGene:672
# 534     BRCA1    NCBIGene:672
# 535     BRCA1    NCBIGene:672
# 536     BRCA1    NCBIGene:672
# 537     BRCA1    NCBIGene:672
# 538     BRCA1    NCBIGene:672
# 539     BRCA1    NCBIGene:672
# 540     BRCA1    NCBIGene:672
# 541     BRCA1    NCBIGene:672
# 542     BRCA1    NCBIGene:672
# 543     BRCA1    NCBIGene:672
# 544     BRCA1    NCBIGene:672
# 545     BRCA1    NCBIGene:672
# 546     BRCA1    NCBIGene:672
# 547     BRCA1    NCBIGene:672
# 548    MAD2L2  NCBIGene:10459
#
#                                           variant_name          variant_curie  \
# 0            NM_000135.2(FANCA):c.3624C>T (p.Ser1208=)  ClinVarVariant:419528
# 1           NM_000135.3(FANCA):c.2398G>T (p.Glu800Ter)  ClinVarVariant:435129
# 2                       NM_000135.3(FANCA):c.2151+1G>A  ClinVarVariant:435130
# 3           NM_000135.2(FANCA):c.2574C>G (p.Ser858Arg)  ClinVarVariant:134256
# 4    NM_000135.2(FANCA):c.3720_3724delAAACA (p.Glu1...    ClinVarVariant:3448
# 5           NM_000135.3(FANCA):c.1340C>G (p.Ser447Ter)  ClinVarVariant:435132
# 6           NM_000135.2(FANCA):c.2762A>T (p.Lys921Ile)  ClinVarVariant:203995
# 7    NC_000016.9:g.(89829945_89831038)_(89836251_89...  ClinVarVariant:402242
# 8        NM_000135.3(FANCA):c.3558dup (p.Arg1187Glufs)    ClinVarVariant:3444
# 9            NM_000135.2(FANCA):c.811C>T (p.Gln271Ter)  ClinVarVariant:371093
# 10   NM_000135.2(FANCA):c.1115_1118delTTGG (p.Val37...    ClinVarVariant:3440
# 11            NM_000135.2(FANCA):c.154C>T (p.Arg52Ter)  ClinVarVariant:371668
# 12                              FANCA, IVS7DS, G-A, +5  ClinVarVariant:192385
# 13                         LRG_495t1:c.1627_1900del274    ClinVarVariant:3439
# 14       NM_000135.2(FANCA):c.1606delT (p.Ser536Glnfs)    ClinVarVariant:3446
# 15   NM_000135.2(FANCA):c.987_990delTCAC (p.His330A...  ClinVarVariant:208580
# 16           NM_000135.3(FANCA):c.513G>A (p.Trp171Ter)    ClinVarVariant:3447
# 17      NM_000135.2(FANCA):c.4015delC (p.Leu1339Serfs)  ClinVarVariant:208638
# 18            NM_000135.2(FANCA):c.295C>T (p.Gln99Ter)  ClinVarVariant:370361
# 19                           FANCA, 156-BP DEL, NT1515    ClinVarVariant:3441
# 20        NM_000135.3(FANCA):c.2839dup (p.Ser947Phefs)  ClinVarVariant:188383
# 21                   NM_000135.2(FANCA):c.1007_3066del    ClinVarVariant:3445
# 22   NC_000016.9:g.(89837128_89837200)_(89847471_89...  ClinVarVariant:402243
# 23         NM_000135.3(FANCA):c.3482C>T (p.Thr1161Met)  ClinVarVariant:435126
# 24               NM_000135.3(FANCA):c.1A>G (p.Met1Val)  ClinVarVariant:435134
# 25       NM_000135.2(FANCA):c.1615delG (p.Asp539Thrfs)    ClinVarVariant:3443
# 26          NM_000135.3(FANCA):c.2557C>T (p.Arg853Ter)  ClinVarVariant:192384
# 27   NM_000135.2(FANCA):c.3761_3762delAG (p.Glu1254...  ClinVarVariant:370466
# 28   NM_000135.2(FANCA):c.3788_3790delTCT (p.Phe126...   ClinVarVariant:41003
# 29                      NM_000135.3(FANCA):c.2601+1G>T  ClinVarVariant:435128
# ..                                                 ...                    ...
# 519  NM_007294.3(BRCA1):c.2529_2530delAA (p.Ser844H...  ClinVarVariant:266274
# 520                     LRG_292:g.160911_164110del3200  ClinVarVariant:373846
# 521       NM_007294.3(BRCA1):c.775delG (p.Glu259Lysfs)   ClinVarVariant:55697
# 522     NM_007294.3(BRCA1):c.5266dupC (p.Gln1756Profs)   ClinVarVariant:17677
# 523      NM_007294.3(BRCA1):c.2933dupA (p.Tyr978Terfs)  ClinVarVariant:236270
# 524      NM_007294.3(BRCA1):c.2778dupT (p.Ala927Cysfs)  ClinVarVariant:266303
# 525         NM_007294.3(BRCA1):c.1059G>A (p.Trp353Ter)   ClinVarVariant:54110
# 526  NM_007294.3(BRCA1):c.2856_2857delTT (p.Phe952L...   ClinVarVariant:54700
# 527        NM_007294.3(BRCA1):c.3412G>T (p.Gly1138Ter)  ClinVarVariant:266367
# 528   NM_007294.3(BRCA1):c.190_211del22 (p.Cys64Glyfs)  ClinVarVariant:266198
# 529  NM_007294.3(BRCA1):c.5221_5224delGTCA (p.Val17...  ClinVarVariant:266536
# 530         NM_007294.3(BRCA1):c.1421T>G (p.Leu474Ter)   ClinVarVariant:54250
# 531         NM_007294.3(BRCA1):c.40delG (p.Val14Serfs)  ClinVarVariant:266443
# 532       NM_007294.3(BRCA1):c.465delA (p.Gln155Hisfs)  ClinVarVariant:254376
# 533      NM_007294.3(BRCA1):c.1823delA (p.Lys608Argfs)   ClinVarVariant:54362
# 534  NM_007294.3(BRCA1):c.5493_5494insTT (p.Val1832...  ClinVarVariant:266555
# 535  NM_007294.3(BRCA1):c.1044_1047delTGAG (p.Cys34...  ClinVarVariant:266134
# 536     NM_007294.3(BRCA1):c.3571delA (p.Ser1191Alafs)  ClinVarVariant:266386
# 537      NM_007294.3(BRCA1):c.2071delA (p.Arg691Aspfs)   ClinVarVariant:37444
# 538     NM_007294.3(BRCA1):c.3108delT (p.Phe1036Leufs)   ClinVarVariant:54771
# 539                     NG_005905.2:g.137094_142043del  ClinVarVariant:373853
# 540  NM_007294.3(BRCA1):c.1881_1884delCAGT (p.Ser62...   ClinVarVariant:54379
# 541     NM_007294.3(BRCA1):c.3862delG (p.Glu1288Lysfs)   ClinVarVariant:55031
# 542  NM_007294.3(BRCA1):c.5300_5301delGT (p.Cys1767...  ClinVarVariant:266543
# 543               NM_007294.3(BRCA1):c.442-?_4357+?del  ClinVarVariant:254055
# 544  NM_007294.3(BRCA1):c.4587_4590delTAAG (p.Ile15...   ClinVarVariant:96935
# 545       NM_007294.3(BRCA1):c.809delA (p.His270Leufs)   ClinVarVariant:55714
# 546  NM_007294.3(BRCA1):c.3482_3492delAAGATACTAGT (...  ClinVarVariant:266374
# 547     NM_007294.3(BRCA1):c.4724delC (p.Pro1575Leufs)   ClinVarVariant:55271
# 548          NM_006341.3(MAD2L2):c.254T>A (p.Val85Glu)  ClinVarVariant:372196
#
#                        relation_name relation_curie  \
# 0    likely_pathogenic_for_condition   GENO:0000841
# 1           pathogenic_for_condition   GENO:0000840
# 2           pathogenic_for_condition   GENO:0000840
# 3           pathogenic_for_condition   GENO:0000840
# 4           pathogenic_for_condition   GENO:0000840
# 5           pathogenic_for_condition   GENO:0000840
# 6    likely_pathogenic_for_condition   GENO:0000841
# 7    likely_pathogenic_for_condition   GENO:0000841
# 8           pathogenic_for_condition   GENO:0000840
# 9    likely_pathogenic_for_condition   GENO:0000841
# 10          pathogenic_for_condition   GENO:0000840
# 11          pathogenic_for_condition   GENO:0000840
# 12          pathogenic_for_condition   GENO:0000840
# 13          pathogenic_for_condition   GENO:0000840
# 14          pathogenic_for_condition   GENO:0000840
# 15          pathogenic_for_condition   GENO:0000840
# 16          pathogenic_for_condition   GENO:0000840
# 17   likely_pathogenic_for_condition   GENO:0000841
# 18          pathogenic_for_condition   GENO:0000840
# 19          pathogenic_for_condition   GENO:0000840
# 20   likely_pathogenic_for_condition   GENO:0000841
# 21          pathogenic_for_condition   GENO:0000840
# 22   likely_pathogenic_for_condition   GENO:0000841
# 23   likely_pathogenic_for_condition   GENO:0000841
# 24          pathogenic_for_condition   GENO:0000840
# 25          pathogenic_for_condition   GENO:0000840
# 26          pathogenic_for_condition   GENO:0000840
# 27          pathogenic_for_condition   GENO:0000840
# 28          pathogenic_for_condition   GENO:0000840
# 29          pathogenic_for_condition   GENO:0000840
# ..                               ...            ...
# 519         pathogenic_for_condition   GENO:0000840
# 520         pathogenic_for_condition   GENO:0000840
# 521         pathogenic_for_condition   GENO:0000840
# 522         pathogenic_for_condition   GENO:0000840
# 523         pathogenic_for_condition   GENO:0000840
# 524         pathogenic_for_condition   GENO:0000840
# 525         pathogenic_for_condition   GENO:0000840
# 526         pathogenic_for_condition   GENO:0000840
# 527         pathogenic_for_condition   GENO:0000840
# 528         pathogenic_for_condition   GENO:0000840
# 529         pathogenic_for_condition   GENO:0000840
# 530         pathogenic_for_condition   GENO:0000840
# 531         pathogenic_for_condition   GENO:0000840
# 532         pathogenic_for_condition   GENO:0000840
# 533         pathogenic_for_condition   GENO:0000840
# 534         pathogenic_for_condition   GENO:0000840
# 535         pathogenic_for_condition   GENO:0000840
# 536         pathogenic_for_condition   GENO:0000840
# 537         pathogenic_for_condition   GENO:0000840
# 538         pathogenic_for_condition   GENO:0000840
# 539         pathogenic_for_condition   GENO:0000840
# 540         pathogenic_for_condition   GENO:0000840
# 541         pathogenic_for_condition   GENO:0000840
# 542         pathogenic_for_condition   GENO:0000840
# 543         pathogenic_for_condition   GENO:0000840
# 544         pathogenic_for_condition   GENO:0000840
# 545         pathogenic_for_condition   GENO:0000840
# 546         pathogenic_for_condition   GENO:0000840
# 547         pathogenic_for_condition   GENO:0000840
# 548         pathogenic_for_condition   GENO:0000840
#
#                                           disease_name disease_curie
# 0              Fanconi Anemia, Complementation Group a   OMIM:227650
# 1              Fanconi Anemia, Complementation Group a   OMIM:227650
# 2              Fanconi Anemia, Complementation Group a   OMIM:227650
# 3              Fanconi Anemia, Complementation Group a   OMIM:227650
# 4              Fanconi Anemia, Complementation Group a   OMIM:227650
# 5              Fanconi Anemia, Complementation Group a   OMIM:227650
# 6              Fanconi Anemia, Complementation Group a   OMIM:227650
# 7              Fanconi Anemia, Complementation Group a   OMIM:227650
# 8              Fanconi Anemia, Complementation Group a   OMIM:227650
# 9              Fanconi Anemia, Complementation Group a   OMIM:227650
# 10             Fanconi Anemia, Complementation Group a   OMIM:227650
# 11             Fanconi Anemia, Complementation Group a   OMIM:227650
# 12             Fanconi Anemia, Complementation Group a   OMIM:227650
# 13             Fanconi Anemia, Complementation Group a   OMIM:227650
# 14             Fanconi Anemia, Complementation Group a   OMIM:227650
# 15             Fanconi Anemia, Complementation Group a   OMIM:227650
# 16             Fanconi Anemia, Complementation Group a   OMIM:227650
# 17             Fanconi Anemia, Complementation Group a   OMIM:227650
# 18             Fanconi Anemia, Complementation Group a   OMIM:227650
# 19             Fanconi Anemia, Complementation Group a   OMIM:227650
# 20             Fanconi Anemia, Complementation Group a   OMIM:227650
# 21             Fanconi Anemia, Complementation Group a   OMIM:227650
# 22             Fanconi Anemia, Complementation Group a   OMIM:227650
# 23             Fanconi Anemia, Complementation Group a   OMIM:227650
# 24             Fanconi Anemia, Complementation Group a   OMIM:227650
# 25             Fanconi Anemia, Complementation Group a   OMIM:227650
# 26             Fanconi Anemia, Complementation Group a   OMIM:227650
# 27             Fanconi Anemia, Complementation Group a   OMIM:227650
# 28             Fanconi Anemia, Complementation Group a   OMIM:227650
# 29             Fanconi Anemia, Complementation Group a   OMIM:227650
# ..                                                 ...           ...
# 519  Breast-Ovarian Cancer, Familial, Susceptibilit...   OMIM:604370
# 520  Breast-Ovarian Cancer, Familial, Susceptibilit...   OMIM:604370
# 521  Breast-Ovarian Cancer, Familial, Susceptibilit...   OMIM:604370
# 522  Breast-Ovarian Cancer, Familial, Susceptibilit...   OMIM:604370
# 523  Breast-Ovarian Cancer, Familial, Susceptibilit...   OMIM:604370
# 524  Breast-Ovarian Cancer, Familial, Susceptibilit...   OMIM:604370
# 525  Breast-Ovarian Cancer, Familial, Susceptibilit...   OMIM:604370
# 526  Breast-Ovarian Cancer, Familial, Susceptibilit...   OMIM:604370
# 527  Breast-Ovarian Cancer, Familial, Susceptibilit...   OMIM:604370
# 528  Breast-Ovarian Cancer, Familial, Susceptibilit...   OMIM:604370
# 529  Breast-Ovarian Cancer, Familial, Susceptibilit...   OMIM:604370
# 530  Breast-Ovarian Cancer, Familial, Susceptibilit...   OMIM:604370
# 531  Breast-Ovarian Cancer, Familial, Susceptibilit...   OMIM:604370
# 532  Breast-Ovarian Cancer, Familial, Susceptibilit...   OMIM:604370
# 533  Breast-Ovarian Cancer, Familial, Susceptibilit...   OMIM:604370
# 534                   hereditary breast ovarian cancer     DOID:5683
# 535  Breast-Ovarian Cancer, Familial, Susceptibilit...   OMIM:604370
# 536  Breast-Ovarian Cancer, Familial, Susceptibilit...   OMIM:604370
# 537  Breast-Ovarian Cancer, Familial, Susceptibilit...   OMIM:604370
# 538  Breast-Ovarian Cancer, Familial, Susceptibilit...   OMIM:604370
# 539  Breast-Ovarian Cancer, Familial, Susceptibilit...   OMIM:604370
# 540  Breast-Ovarian Cancer, Familial, Susceptibilit...   OMIM:604370
# 541  Breast-Ovarian Cancer, Familial, Susceptibilit...   OMIM:604370
# 542  Breast-Ovarian Cancer, Familial, Susceptibilit...   OMIM:604370
# 543                   hereditary breast ovarian cancer     DOID:5683
# 544  Breast-Ovarian Cancer, Familial, Susceptibilit...   OMIM:604370
# 545  Breast-Ovarian Cancer, Familial, Susceptibilit...   OMIM:604370
# 546  Breast-Ovarian Cancer, Familial, Susceptibilit...   OMIM:604370
# 547  Breast-Ovarian Cancer, Familial, Susceptibilit...   OMIM:604370
# 548            Fanconi Anemia, Complementation Group 5   OMIM:617243
#
# [549 rows x 8 columns]

# %%
pwd
# Out:
# '/Users/timputman/CODE/NCATS/cq_notebooks/cq-notebooks/Orange_QB1_Benchmark_CQs/QB1.2_FA_Gene_Pathogenic_Variants'
