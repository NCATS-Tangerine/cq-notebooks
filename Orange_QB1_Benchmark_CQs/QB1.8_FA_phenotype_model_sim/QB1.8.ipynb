# %%
import pandas as pd
import requests
from pprint import pprint
from collections import defaultdict

# %%
# get gene sets from github
base_url = "https://raw.githubusercontent.com/NCATS-Tangerine/cq-notebooks/master/FA_gene_sets/"
FA_1_core_complex = "FA_1_core_complex.txt"
columns = ['gene_curie', 'gene_symbol']
fa_genes = pd.read_csv(base_url + FA_1_core_complex, sep='\t', names=columns)

# %%
fa_genes
# Out:
#         gene_curie gene_symbol
# 0    NCBIGene:2175       FANCA
# 1    NCBIGene:2187       FANCB
# 2    NCBIGene:2176       FANCC
# 3    NCBIGene:2178       FANCE
# 4    NCBIGene:2188       FANCF
# 5    NCBIGene:2189       FANCG
# 6   NCBIGene:55120       FANCL
# 7   NCBIGene:57697       FANCM
# 8    NCBIGene:2177      FANCD2
# 9   NCBIGene:55215       FANCI
# 10  NCBIGene:29089       UBE2T

# %%
def get_orthologs(gene_curie):
    url = 'https://api.monarchinitiative.org/api/bioentity/gene/{}/homologs/'.format(gene_curie)
    response = requests.get(url)
    return response.json()

def get_phenotypes(gene_curie):
    url = 'https://api.monarchinitiative.org/api/bioentity/gene/{}/phenotypes/'.format(gene_curie)
    response = requests.get(url)
    return response.json()

# %%
ortho_pheno = list()
for index, gene in fa_genes.iterrows():
    orhtologs = get_orthologs(gene[0])
    for assoc in orhtologs['associations']:
        phenotypes = get_phenotypes(assoc['object']['id'])
        if len(phenotypes['associations']) > 0:
            for passoc in phenotypes['associations']:
                result = {
                    'gene_name': gene[1], 
                    'gene_curie': gene[0], 
                    'ortholog_name': assoc['object']['label'], 
                    'ortholog_curie': assoc['object']['id'], 
                    'model_name':  assoc['object']['taxon']['label'], 
                    'model_curie': assoc['object']['taxon']['id'],
                    'phenotype_name': passoc['object']['label'], 
                    'phenotype_curie': passoc['object']['id']
                }
                ortho_pheno.append(result)
columns = ['gene_name', 'gene_curie', 'ortholog_name', 'ortholog_curie', 'model_name', 'model_curie', 'phenotype_name', 'phenotype_curie'] 
phenotypes = pd.DataFrame(data=ortho_pheno, columns=columns)
phenotypes
# Out:
#     gene_name      gene_curie ortholog_name           ortholog_curie  \
# 0       FANCA   NCBIGene:2175         Fanca              MGI:1341823
# 1       FANCA   NCBIGene:2175         Fanca              MGI:1341823
# 2       FANCA   NCBIGene:2175         Fanca              MGI:1341823
# 3       FANCA   NCBIGene:2175         Fanca              MGI:1341823
# 4       FANCA   NCBIGene:2175         Fanca              MGI:1341823
# 5       FANCA   NCBIGene:2175         Fanca              MGI:1341823
# 6       FANCA   NCBIGene:2175         Fanca              MGI:1341823
# 7       FANCA   NCBIGene:2175         Fanca              MGI:1341823
# 8       FANCA   NCBIGene:2175         Fanca              MGI:1341823
# 9       FANCA   NCBIGene:2175         Fanca              MGI:1341823
# 10      FANCA   NCBIGene:2175         Fanca              MGI:1341823
# 11      FANCA   NCBIGene:2175         Fanca              MGI:1341823
# 12      FANCA   NCBIGene:2175         Fanca              MGI:1341823
# 13      FANCA   NCBIGene:2175         Fanca              MGI:1341823
# 14      FANCA   NCBIGene:2175         Fanca              MGI:1341823
# 15      FANCA   NCBIGene:2175         Fanca              MGI:1341823
# 16      FANCA   NCBIGene:2175         Fanca              MGI:1341823
# 17      FANCA   NCBIGene:2175         Fanca              MGI:1341823
# 18      FANCA   NCBIGene:2175         Fanca              MGI:1341823
# 19      FANCA   NCBIGene:2175         Fanca              MGI:1341823
# 20      FANCA   NCBIGene:2175         Fanca              MGI:1341823
# 21      FANCA   NCBIGene:2175         Fanca              MGI:1341823
# 22      FANCA   NCBIGene:2175         Fanca              MGI:1341823
# 23      FANCA   NCBIGene:2175         Fanca              MGI:1341823
# 24      FANCA   NCBIGene:2175         Fanca              MGI:1341823
# 25      FANCA   NCBIGene:2175         Fanca              MGI:1341823
# 26      FANCA   NCBIGene:2175         Fanca              MGI:1341823
# 27      FANCA   NCBIGene:2175         Fanca              MGI:1341823
# 28      FANCA   NCBIGene:2175         Fanca              MGI:1341823
# 29      FANCA   NCBIGene:2175         Fanca              MGI:1341823
# ..        ...             ...           ...                      ...
# 184    FANCD2   NCBIGene:2177        Fancd2              MGI:2448480
# 185    FANCD2   NCBIGene:2177        Fancd2              MGI:2448480
# 186    FANCD2   NCBIGene:2177        Fancd2              MGI:2448480
# 187    FANCD2   NCBIGene:2177        Fancd2              MGI:2448480
# 188    FANCD2   NCBIGene:2177        Fancd2              MGI:2448480
# 189    FANCD2   NCBIGene:2177        Fancd2              MGI:2448480
# 190    FANCD2   NCBIGene:2177        Fancd2              MGI:2448480
# 191    FANCD2   NCBIGene:2177        Fancd2              MGI:2448480
# 192    FANCD2   NCBIGene:2177        Fancd2              MGI:2448480
# 193    FANCD2   NCBIGene:2177        Fancd2              MGI:2448480
# 194    FANCD2   NCBIGene:2177        Fancd2              MGI:2448480
# 195    FANCD2   NCBIGene:2177        Fancd2              MGI:2448480
# 196    FANCD2   NCBIGene:2177        Fancd2              MGI:2448480
# 197    FANCD2   NCBIGene:2177        Fancd2              MGI:2448480
# 198    FANCD2   NCBIGene:2177        Fancd2              MGI:2448480
# 199    FANCD2   NCBIGene:2177        Fancd2              MGI:2448480
# 200    FANCD2   NCBIGene:2177        Fancd2              MGI:2448480
# 201    FANCD2   NCBIGene:2177        Fancd2              MGI:2448480
# 202    FANCD2   NCBIGene:2177        Fancd2              MGI:2448480
# 203    FANCD2   NCBIGene:2177        Fancd2              MGI:2448480
# 204    FANCD2   NCBIGene:2177        Fancd2      FlyBase:FBgn0038827
# 205    FANCD2   NCBIGene:2177        Fancd2      FlyBase:FBgn0038827
# 206    FANCD2   NCBIGene:2177        Fancd2      FlyBase:FBgn0038827
# 207    FANCD2   NCBIGene:2177        Fancd2      FlyBase:FBgn0038827
# 208    FANCD2   NCBIGene:2177        Fancd2      FlyBase:FBgn0038827
# 209    FANCD2   NCBIGene:2177        Fancd2      FlyBase:FBgn0038827
# 210     FANCI  NCBIGene:55215         FANCI      FlyBase:FBgn0033354
# 211     FANCI  NCBIGene:55215         FANCI      FlyBase:FBgn0033354
# 212     FANCI  NCBIGene:55215        fnci-1  WormBase:WBGene00020935
# 213     FANCI  NCBIGene:55215         Fanci              MGI:2384790
#
#                   model_name      model_curie  \
# 0               Mus musculus  NCBITaxon:10090
# 1               Mus musculus  NCBITaxon:10090
# 2               Mus musculus  NCBITaxon:10090
# 3               Mus musculus  NCBITaxon:10090
# 4               Mus musculus  NCBITaxon:10090
# 5               Mus musculus  NCBITaxon:10090
# 6               Mus musculus  NCBITaxon:10090
# 7               Mus musculus  NCBITaxon:10090
# 8               Mus musculus  NCBITaxon:10090
# 9               Mus musculus  NCBITaxon:10090
# 10              Mus musculus  NCBITaxon:10090
# 11              Mus musculus  NCBITaxon:10090
# 12              Mus musculus  NCBITaxon:10090
# 13              Mus musculus  NCBITaxon:10090
# 14              Mus musculus  NCBITaxon:10090
# 15              Mus musculus  NCBITaxon:10090
# 16              Mus musculus  NCBITaxon:10090
# 17              Mus musculus  NCBITaxon:10090
# 18              Mus musculus  NCBITaxon:10090
# 19              Mus musculus  NCBITaxon:10090
# 20              Mus musculus  NCBITaxon:10090
# 21              Mus musculus  NCBITaxon:10090
# 22              Mus musculus  NCBITaxon:10090
# 23              Mus musculus  NCBITaxon:10090
# 24              Mus musculus  NCBITaxon:10090
# 25              Mus musculus  NCBITaxon:10090
# 26              Mus musculus  NCBITaxon:10090
# 27              Mus musculus  NCBITaxon:10090
# 28              Mus musculus  NCBITaxon:10090
# 29              Mus musculus  NCBITaxon:10090
# ..                       ...              ...
# 184             Mus musculus  NCBITaxon:10090
# 185             Mus musculus  NCBITaxon:10090
# 186             Mus musculus  NCBITaxon:10090
# 187             Mus musculus  NCBITaxon:10090
# 188             Mus musculus  NCBITaxon:10090
# 189             Mus musculus  NCBITaxon:10090
# 190             Mus musculus  NCBITaxon:10090
# 191             Mus musculus  NCBITaxon:10090
# 192             Mus musculus  NCBITaxon:10090
# 193             Mus musculus  NCBITaxon:10090
# 194             Mus musculus  NCBITaxon:10090
# 195             Mus musculus  NCBITaxon:10090
# 196             Mus musculus  NCBITaxon:10090
# 197             Mus musculus  NCBITaxon:10090
# 198             Mus musculus  NCBITaxon:10090
# 199             Mus musculus  NCBITaxon:10090
# 200             Mus musculus  NCBITaxon:10090
# 201             Mus musculus  NCBITaxon:10090
# 202             Mus musculus  NCBITaxon:10090
# 203             Mus musculus  NCBITaxon:10090
# 204  Drosophila melanogaster   NCBITaxon:7227
# 205  Drosophila melanogaster   NCBITaxon:7227
# 206  Drosophila melanogaster   NCBITaxon:7227
# 207  Drosophila melanogaster   NCBITaxon:7227
# 208  Drosophila melanogaster   NCBITaxon:7227
# 209  Drosophila melanogaster   NCBITaxon:7227
# 210  Drosophila melanogaster   NCBITaxon:7227
# 211  Drosophila melanogaster   NCBITaxon:7227
# 212   Caenorhabditis elegans   NCBITaxon:6239
# 213             Mus musculus  NCBITaxon:10090
#
#                                         phenotype_name         phenotype_curie
# 0                       Abnormality of cell physiology              HP:0011017
# 1                             absent ovarian follicles              MP:0002777
# 2                                     Thrombocytopenia              HP:0001873
# 3                   female gonad development phenotype     GO:0008585PHENOTYPE
# 4                          abnormal cranium morphology              MP:0000438
# 5                         embryonic growth retardation              MP:0003984
# 6                             Abnormality of the ovary              HP:0000137
# 7                                     ovary hemorrhage              MP:0004834
# 8                            Decreased testicular size              HP:0008734
# 9                      Hyperplasia of the Leydig cells              HP:0010791
# 10                               decreased litter size              MP:0001935
# 11                            reduced female fertility              MP:0001923
# 12                   Increased mean corpuscular volume              HP:0005518
# 13                                  skeleton phenotype              MP:0005390
# 14                                 Female hypogonadism              HP:0000134
# 15                                        Ovarian cyst              HP:0000138
# 16                              male meiosis phenotype     GO:0007140PHENOTYPE
# 17                          decreased germ cell number              MP:0002209
# 18   increased physiological sensitivity to xenobiotic              MP:0008873
# 19                   abnormal male germ cell apoptosis              MP:0008280
# 20   regulation of sequence-specific DNA binding tr...     GO:0051090PHENOTYPE
# 21                          small seminiferous tubules              MP:0001153
# 22                                            Neoplasm              HP:0002664
# 23          regulation of cell proliferation phenotype     GO:0042127PHENOTYPE
# 24                                        Hypogonadism              HP:0000135
# 25                                 Chromosome breakage              HP:0040012
# 26                               Decreased body weight              HP:0004325
# 27                    male gonad development phenotype     GO:0008584PHENOTYPE
# 28       regulation of inflammatory response phenotype     GO:0050727PHENOTYPE
# 29                               abnormal male meiosis              MP:0005169
# ..                                                 ...                     ...
# 184                                     Microphthalmia              HP:0000568
# 185                        increased adenoma incidence              MP:0010383
# 186                                        Infertility              HP:0000789
# 187                              abnormal male meiosis              MP:0005169
# 188            abnormal seminiferous tubule morphology              MP:0002216
# 189        increased sensitivity to induced cell death              MP:0008943
# 190                                    Mortality/Aging              HP:0040006
# 191         perinatal lethality, incomplete penetrance              MP:0011090
# 192  cellular response to DNA damage stimulus pheno...     GO:0006974PHENOTYPE
# 193                                       Oligospermia              HP:0000798
# 194  regulation of sequence-specific DNA binding tr...     GO:0051090PHENOTYPE
# 195                                 synapsis phenotype     GO:0007129PHENOTYPE
# 196  increased physiological sensitivity to xenobiotic              MP:0008873
# 197      regulation of inflammatory response phenotype     GO:0050727PHENOTYPE
# 198           decreased mature ovarian follicle number              MP:0002682
# 199           decreased hematopoietic stem cell number              MP:0004810
# 200                          Decreased testicular size              HP:0008734
# 201                              Decreased body weight              HP:0004325
# 202                           fetal growth retardation              MP:0004201
# 203                                          Carcinoma              HP:0030731
# 204           Drosophila mesothoracic tergum phenotype  FBbt:00004580PHENOTYPE
# 205                                   flight defective            FBcv:0000417
# 206                                             viable            FBcv:0000349
# 207                Drosophila trichogen cell phenotype  FBbt:00005169PHENOTYPE
# 208                                          phenotype            FBcv:0001347
# 209                                            visible            FBcv:0000354
# 210                                             viable            FBcv:0000349
# 211                                          phenotype            FBcv:0001347
# 212                                   embryonic lethal     WBPhenotype:0000050
# 213        preweaning lethality, incomplete penetrance              MP:0011110
#
# [214 rows x 8 columns]

# %%
OWLSIM_API = "http://owlsim3.monarchinitiative.org/api"
# Use phenodigm algorithm, with a cutoff of 70/100
matcher = 'phenodigm'
score_cutoff = 70
result_set = []
for index, row in fa_genes.iterrows():
    if index < 10:
        phenos = phenotypes['phenotype_curie'].tolist()
        params = {
            'id': phenos
        }
        url = "{}/match/{}".format(OWLSIM_API, matcher)
        req = requests.get(url, params=params)
        owlsim_results = req.json()
        try:
            for match in owlsim_results['matches']:
                if match['rawScore'] >= score_cutoff:
                    pprint(match)
#                 pprint(match)
#                 result = [row['gene_curie'],index, match['matchId'],
#                           match['matchLabel'], match['rawScore']]
#                 result_set.append(result)
        except TypeError as e:
            # TypeError when score is NaN
            #print(e)
            #print(match)
            continue


# # # Create a table of query gene, matched gene, and sim score
column_names = ['query_gene', 'query_symbol', 'match_gene', 'match_symbol', 'sim_score']
result_frame = pd.DataFrame(data=result_set, columns=column_names)
result_set
# Out:
# {'matchId': 'MGI:1341823',
#  'matchLabel': 'Fanca',
#  'percentageScore': 7313,
#  'rank': 1,
#  'rawScore': 73.12643145053599,
#  'score': 7312.643145053599,
#  'significance': 'NaN'}
# {'matchId': 'MGI:1914280',
#  'matchLabel': 'Fancl',
#  'percentageScore': 7016,
#  'rank': 2,
#  'rawScore': 70.1562345616751,
#  'score': 7015.623456167511,
#  'significance': 'NaN'}
# {'matchId': 'MGI:1341823',
#  'matchLabel': 'Fanca',
#  'percentageScore': 7313,
#  'rank': 1,
#  'rawScore': 73.12643145053599,
#  'score': 7312.643145053599,
#  'significance': 'NaN'}
# {'matchId': 'MGI:1914280',
#  'matchLabel': 'Fancl',
#  'percentageScore': 7016,
#  'rank': 2,
#  'rawScore': 70.1562345616751,
#  'score': 7015.623456167511,
#  'significance': 'NaN'}
# {'matchId': 'MGI:1341823',
#  'matchLabel': 'Fanca',
#  'percentageScore': 7313,
#  'rank': 1,
#  'rawScore': 73.12643145053599,
#  'score': 7312.643145053599,
#  'significance': 'NaN'}
# {'matchId': 'MGI:1914280',
#  'matchLabel': 'Fancl',
#  'percentageScore': 7016,
#  'rank': 2,
#  'rawScore': 70.1562345616751,
#  'score': 7015.623456167511,
#  'significance': 'NaN'}
# {'matchId': 'MGI:1341823',
#  'matchLabel': 'Fanca',
#  'percentageScore': 7313,
#  'rank': 1,
#  'rawScore': 73.12643145053599,
#  'score': 7312.643145053599,
#  'significance': 'NaN'}
# {'matchId': 'MGI:1914280',
#  'matchLabel': 'Fancl',
#  'percentageScore': 7016,
#  'rank': 2,
#  'rawScore': 70.1562345616751,
#  'score': 7015.623456167511,
#  'significance': 'NaN'}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/timputman/.virtualenvs/QB1_2/lib/python3.5/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-56-db0ffa09aa60> in <module>()
#      11         }
#      12         url = "{}/match/{}".format(OWLSIM_API, matcher)
# ---> 13         req = requests.get(url, params=params)
#      14         owlsim_results = req.json()
#      15         try:
#
# /Users/timputman/.virtualenvs/QB1_2/lib/python3.5/site-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# /Users/timputman/.virtualenvs/QB1_2/lib/python3.5/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# /Users/timputman/.virtualenvs/QB1_2/lib/python3.5/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# /Users/timputman/.virtualenvs/QB1_2/lib/python3.5/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# /Users/timputman/.virtualenvs/QB1_2/lib/python3.5/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# /Users/timputman/.virtualenvs/QB1_2/lib/python3.5/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# /Users/timputman/.virtualenvs/QB1_2/lib/python3.5/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#     385                     # Remove the TypeError from the exception chain in Python 3;
#
# /usr/local/Cellar/python3/3.5.1/Frameworks/Python.framework/Versions/3.5/lib/python3.5/http/client.py in getresponse(self)
#    1172         try:
#    1173             try:
# -> 1174                 response.begin()
#    1175             except ConnectionError:
#    1176                 self.close()
#
# /usr/local/Cellar/python3/3.5.1/Frameworks/Python.framework/Versions/3.5/lib/python3.5/http/client.py in begin(self)
#     280         # read until we get a non-100 response
#     281         while True:
# --> 282             version, status, reason = self._read_status()
#     283             if status != CONTINUE:
#     284                 break
#
# /usr/local/Cellar/python3/3.5.1/Frameworks/Python.framework/Versions/3.5/lib/python3.5/http/client.py in _read_status(self)
#     241
#     242     def _read_status(self):
# --> 243         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     244         if len(line) > _MAXLINE:
#     245             raise LineTooLong("status line")
#
# /usr/local/Cellar/python3/3.5.1/Frameworks/Python.framework/Versions/3.5/lib/python3.5/socket.py in readinto(self, b)
#     573         while True:
#     574             try:
# --> 575                 return self._sock.recv_into(b)
#     576             except timeout:
#     577                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
result_set
# Out:
# []
